# %% [markdown]
# <!--HEADER-->
# [*Test dir 2 for the nbbinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/05.02-Compound_Sentences.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/05.02-Compound_Sentences.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
#
# [<- Complex Sentences](05.01-Complex_Sentences.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Paragraphs ->](06.00-Paragraphs.ipynb)
#
# ---

# %% [markdown]
# # Compound Sentences

# %% [markdown]
# That's all for this Section

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Complex Sentences](05.01-Complex_Sentences.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Paragraphs ->](06.00-Paragraphs.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/05.02-Compound_Sentences.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/05.02-Compound_Sentences.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
