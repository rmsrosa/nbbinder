# %% [markdown]
# <!--HEADER-->
# [*Test dir 2 for the nbbinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/BA.00-Index.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/BA.00-Index.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
#
# [<- Glossary](BA.00-Glossary.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography ->](BB.00-Bibliography.ipynb)
#
# ---

# %% [markdown]
# # Index

# %% [markdown]
# That's all for this part of the End Matter

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Glossary](BA.00-Glossary.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography ->](BB.00-Bibliography.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/BA.00-Index.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/BA.00-Index.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
