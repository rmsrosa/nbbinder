# %% [markdown]
# <!--HEADER-->
# [*Test Grammar for the NBBinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
#
# [<- Glossary](BA.00-Glossary.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Bibliography ->](BB.00-Bibliography.ipynb)
#
# ---

# %% [markdown]
# <!--NAVIGATOR-->
#
# [<- Glossary](BA.00-Glossary.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography ->](BB.00-Bibliography.ipynb)
#
# ---

# %% [markdown]
# # Index

# %% [markdown]
# That's all for this part of the End Matter

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Glossary](BA.00-Glossary.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Bibliography ->](BB.00-Bibliography.ipynb)
