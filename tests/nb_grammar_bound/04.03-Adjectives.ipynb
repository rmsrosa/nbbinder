# %% [markdown]
# <!--HEADER-->
# [*Test Grammar for the NBBinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
#
# [<- Verbs](04.02-Verbs.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Adverbs ->](04.04-Adverbs.ipynb)
#
# ---

# %% [markdown]
# <!--NAVIGATOR-->
#
# [<- Verbs](04.02-Verbs.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Adverbs ->](04.04-Adverbs.ipynb)
#
# ---

# %% [markdown]
# # Adjectives

# %% [markdown]
# That's all for this Section

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Verbs](04.02-Verbs.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Adverbs ->](04.04-Adverbs.ipynb)
