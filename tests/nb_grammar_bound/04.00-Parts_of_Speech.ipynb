# %% [markdown]
# <!--HEADER-->
# [*Test dir 2 for the nbbinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/04.00-Parts_of_Speech.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/04.00-Parts_of_Speech.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
#
# [<- The History of Grammar](03.00-The_History_of_Grammar.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Nouns ->](04.01-Nouns.ipynb)
#
# ---

# %% [markdown]
# # Parts of Speech

# %% [markdown]
# That's all for this Section

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- The History of Grammar](03.00-The_History_of_Grammar.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Nouns ->](04.01-Nouns.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/04.00-Parts_of_Speech.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/04.00-Parts_of_Speech.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
