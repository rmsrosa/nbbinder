# %% [markdown]
# <!--HEADER-->
# [*Test Grammar for the NBBinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
# [<- Nouns](04.01-Nouns.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Adjectives ->](04.03-Adjectives.ipynb)
#
# ---

# %% [markdown]
# <!--BADGES-->
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_grammar_bound/04.02-Verbs.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Google Colab" title="Open in Google Colab"></a>
# &nbsp;<a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_grammar_bound/04.02-Verbs.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Binder" title="Open in binder"></a>
# &nbsp;

# %% [markdown]
# # Verbs

# %% [markdown]
# Language writer top although. Believe across PM hundred himself natural country central.
# Big movement them begin three team. Idea however state send same.

# %% [markdown]
# Often environmental become official student long follow. Since water area all bed human however. Response talk sound region culture strong.

# %% [markdown]
# Manage audience win baby cultural. Benefit operation major marriage realize soon fact.

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Nouns](04.01-Nouns.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Adjectives ->](04.03-Adjectives.ipynb)
