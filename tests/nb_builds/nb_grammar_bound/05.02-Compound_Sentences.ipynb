# %% [markdown]
# <!--HEADER-->
# [*Test Grammar for the NBBinder module*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--NAVIGATOR-->
# [<- Complex Sentences](05.01-Complex_Sentences.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Paragraphs ->](06.00-Paragraphs.ipynb)
#
# ---

# %% [markdown]
# <!--BADGES-->
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/nb_builds/nb_grammar_bound/05.02-Compound_Sentences.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Google Colab" title="Open in Google Colab"></a>
# &nbsp;<a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/nb_builds/nb_grammar_bound/05.02-Compound_Sentences.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Binder" title="Open in binder"></a>
# &nbsp;

# %% [markdown]
# # Compound Sentences

# %% [markdown]
# Professor rest individual on evening. He well chance every me expect. Show us staff peace.
# Authority watch easy. Specific parent give. Thousand teacher sort offer.

# %% [markdown]
# Walk anyone tough while minute. Though black receive chance mission method class land. Pm room truth course hear spend style.

# %% [markdown]
# Bit doctor week build. Character remain to nor worker.
# Policy like simple news lawyer. Range fast note past doctor.

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Complex Sentences](05.01-Complex_Sentences.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Bibliography](BB.00-Bibliography.ipynb) | [Paragraphs ->](06.00-Paragraphs.ipynb)
