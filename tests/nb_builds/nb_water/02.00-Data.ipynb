# %% [markdown]
# <!--HEADER-->
# [*NBBinder test on a collection of notebooks about some thermodynamic properperties of water*](https://github.com/rmsrosa/nbbinder)

# %% [markdown]
# <!--BADGES-->
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/nb_builds/tests/nb_alice/02.00-Data.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Google Colab" title="Open in Google Colab"></a>
# &nbsp;<a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=nb_builds/tests/nb_alice/02.00-Data.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Binder" title="Open in binder"></a>
# &nbsp;<a href="https://nbviewer.jupyter.org/github/rmsrosa/nbbinder/blob/master/nb_builds/tests/nb_water/02.00-Data.ipynb"><img align="left" src="https://img.shields.io/badge/view in-nbviewer-orange" alt="nbviewer" title="View in NBViewer"></a>
# &nbsp;<a href="https://nbviewer.jupyter.org/github/rmsrosa/nbbinder/blob/master/tests/nb_builds/nb_water_slides/02.00-Data.slides.html"><img align="left" src="https://img.shields.io/badge/view-slides-darkgreen" alt="slides" title="View Slides"></a>
# &nbsp;

# %% [markdown]
# <!--NAVIGATOR-->
# [<- Introduction](01.00-Introduction.ipynb) | [Water](00.00-Water.ipynb) | [References](BA.00-References.ipynb) | [Linear and Quadratic Fittings ->](03.00-Linear_and_Quadratic_Fittings.ipynb)
#
# ---

# %% [markdown]
# # Density and viscosity data in terms of temperature
#
# A table with the (isobaric) variation of density and viscosity in terms of the temperature, at $1$ atmosphere, is available in [Batchelor (2000)](BA.00-References.ipynb).

# %% [markdown]
# ## Importing the libraries

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the data
#
# This data has been copied and saved to the local csv file `water.csv`. We retrieve it in both numpy and pandas as follows.

# %%
file = 'water.csv'

water_np = np.loadtxt(open(file, "rb"), delimiter=",", skiprows=2)
water_pd = pd.read_csv(file, header=[0,1])

# %% [markdown]
# ## Showing the data

# %% [markdown]
# The first five columns of data:

# %%
water_pd.head()
# Out:
#              temp           density           viscosity
#   Temperature (C)  Density (g/cm^3)  Viscosity (cm^2/s)
# 0               0            0.9999             0.01787
# 1               5            1.0000             1.51400
# 2              10            0.9997             1.30400
# 3              15            0.9991             1.13800
# 4              20            0.9982             1.00400

# %% [markdown]
# And the full set of data:

# %%
water_pd
# Out:
#               temp           density           viscosity
#    Temperature (C)  Density (g/cm^3)  Viscosity (cm^2/s)
# 0                0            0.9999             0.01787
# 1                5            1.0000             1.51400
# 2               10            0.9997             1.30400
# 3               15            0.9991             1.13800
# 4               20            0.9982             1.00400
# 5               25            0.9971             0.89400
# 6               30            0.9957             0.80200
# 7               35            0.9941             0.72500
# 8               40            0.9923             0.65900
# 9               50            0.9881             0.55400
# 10              60            0.9832             0.47500
# 11              70            0.9778             0.41400
# 12              80            0.9718             0.36600
# 13              90            0.9653             0.32700
# ...

# %% [markdown]
# ## Plotting the data

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel(list(water_pd)[0][1])
ax1.set_ylabel(list(water_pd)[1][1], color=color) 
ax1.plot(water_np[:,0], water_np[:,1], 'o', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:red'
ax2.set_ylabel(list(water_pd)[2][1], color=color)
ax2.plot(water_np[:,0], water_np[:,2], 'o', color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.show()

# %% [markdown]
# ## Density
#
# Here, we will focus on the dependency of the density on the temperature:

# %%
fig = plt.figure()

color = 'tab:blue'
plt.xlabel(list(water_pd)[0][1])
plt.ylabel(list(water_pd)[1][1], color=color) 
plt.plot(water_np[:,0], water_np[:,1], 'o', color=color)
plt.tick_params(axis='y', labelcolor=color)

plt.show()

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Introduction](01.00-Introduction.ipynb) | [Water](00.00-Water.ipynb) | [References](BA.00-References.ipynb) | [Linear and Quadratic Fittings ->](03.00-Linear_and_Quadratic_Fittings.ipynb)
