# %% [markdown]
# <!--HEADER-->
# *[Test dir 2 for the nbbinder module](https://github.com/rmsrosa/nbbinder)*

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/notebooks/01.00-The_Beginnings.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/notebooks/01.00-The_Beginnings.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
#
# [<- Introduction](00.03-Introduction.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Joyful Years ->](01.01-Joyful_Years.ipynb)
#
# ---

# %% [markdown]
# # The Beginnings

# %% [markdown]
# That's all for this Section

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Introduction](00.03-Introduction.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Joyful Years ->](01.01-Joyful_Years.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/notebooks/01.00-The_Beginnings.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/notebooks/01.00-The_Beginnings.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
