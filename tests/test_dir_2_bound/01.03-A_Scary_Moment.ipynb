# %% [markdown]
# <!--HEADER-->
# *[Test dir 2 for the nbbinder module](https://github.com/rmsrosa/nbbinder)*

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/notebooks/01.03-A_Scary_Moment.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/notebooks/01.03-A_Scary_Moment.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
#
# [<- First Steps](01.02-First_Steps.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Back to Normal ->](01.04-Back_to_Normal.ipynb)
#
# ---

# %% [markdown]
# # A Scary Moment

# %% [markdown]
# That's all for this Section

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- First Steps](01.02-First_Steps.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Back to Normal ->](01.04-Back_to_Normal.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/notebooks/01.03-A_Scary_Moment.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/notebooks/01.03-A_Scary_Moment.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
