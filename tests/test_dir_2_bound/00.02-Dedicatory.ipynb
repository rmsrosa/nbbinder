# %% [markdown]
# <!--HEADER-->
# *[Test dir 2 for the nbbinder module](https://github.com/rmsrosa/nbbinder)*

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/notebooks/00.02-Dedicatory.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/notebooks/00.02-Dedicatory.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
#
# [<- Foreword](00.01-Foreword.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Introduction ->](00.03-Introduction.ipynb)
#
# ---

# %% [markdown]
# # Dedicatory

# %% [markdown]
# That's all for this part of the Front Matter

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# [<- Foreword](00.01-Foreword.ipynb) | [Front Page](00.00-Front_Page.ipynb) | [Introduction ->](00.03-Introduction.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/nbbinder/blob/master/tests/notebooks/00.02-Dedicatory.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/nbbinder/master?filepath=tests/notebooks/00.02-Dedicatory.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
